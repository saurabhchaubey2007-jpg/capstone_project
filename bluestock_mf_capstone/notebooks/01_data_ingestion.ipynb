# %%
import pandas as pd

fund_master = pd.read_csv("../data/raw/01_fund_master.csv")

fund_master.head()
# Out:
#    amfi_code       fund_house                                   scheme_name  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth
# 2     119598  SBI Mutual Fund    SBI Small Cap Fund - Regular Plan - Growth
# 3     119599  SBI Mutual Fund     SBI Small Cap Fund - Direct Plan - Growth
# 4     119120  SBI Mutual Fund  SBI Magnum Gilt Fund - Regular Plan - Growth
#
#   category sub_category     plan launch_date                  benchmark  \
# 0   Equity    Large Cap  Regular  2006-02-14              NIFTY 100 TRI
# 1   Equity    Large Cap   Direct  2013-01-01              NIFTY 100 TRI
# 2   Equity    Small Cap  Regular  2009-09-09       BSE 250 SmallCap TRI
# 3   Equity    Small Cap   Direct  2013-01-01       BSE 250 SmallCap TRI
# 4     Debt         Gilt  Regular  2000-12-30  CRISIL Dynamic Gilt Index
#
#    expense_ratio_pct  exit_load_pct  min_sip_amount  min_lumpsum_amount  \
# ...

# %%
fund_master["fund_house"]
fund_master["category"]
fund_master["sub_category"]
fund_master["risk_category"]
# Out:
# 0            Moderate
# 1            Moderate
# 2           Very High
# 3           Very High
# 4                 Low
# 5            Moderate
# 6            Moderate
# 7                High
# 8                High
# 9                 Low
# 10           Moderate
# 11           Moderate
# 12               High
# 13    Moderately High
# 14                Low
# 15           Moderate
# 16           Moderate
# 17          Very High
# 18           Moderate
# 19                Low
# 20           Moderate
# 21               High
# 22    Moderately High
# 23                Low
# 24           Moderate
# 25           Moderate
# 26               High
# 27          Very High
# 28           Moderate
# 29          Very High
# 30                Low
# 31           Moderate
# 32               High
# 33    Moderately High
# 34           Moderate
# 35    Moderately High
# 36               High
# 37           Moderate
# 38               High
# 39          Very High
# Name: risk_category, dtype: object

# %%
print(fund_master["risk_category"].value_counts())
# Out:
# risk_category
# Moderate           16
# High                8
# Very High           6
# Low                 6
# Moderately High     4
# Name: count, dtype: int64

# %%
nav_history = pd.read_csv("../data/raw/02_nav_history.csv")

fund_codes = set(fund_master["amfi_code"])
nav_codes = set(nav_history["amfi_code"])

missing_codes = fund_codes - nav_codes

print("Missing Codes:")
print(missing_codes)

print("\nTotal Fund Codes:", len(fund_codes))
print("Total NAV Codes:", len(nav_codes))
# Out:
# Missing Codes:
# set()
#
# Total Fund Codes: 40
# Total NAV Codes: 40

# %%
fund_master.isnull().sum()
# Out:
# amfi_code             0
# fund_house            0
# scheme_name           0
# category              0
# sub_category          0
# plan                  0
# launch_date           0
# benchmark             0
# expense_ratio_pct     0
# exit_load_pct         0
# min_sip_amount        0
# min_lumpsum_amount    0
# fund_manager          0
# risk_category         0
# sebi_category_code    0
# dtype: int64

# %% [markdown]
# # Data Quality Summary
#
# ## Successfully loaded all 10 datasets.
# ## Verified dataset shapes, columns and data types.
# ## No critical missing values detected.
#
#
#
# ## 12 missing values observed in yoy_growth_pct of monthly SIP dataset; expected because YoY growth cannot be calculated for the initial months.
# ##  All AMFI scheme codes in fund_master successfully matched with nav_history.
# ##  No duplicate scheme code issues identified.
